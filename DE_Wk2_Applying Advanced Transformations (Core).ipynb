# %%
#Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Import OS and JSON Modules
import os,json

# %% [markdown]
# # Part I

# %%
#read in first file to a DF
sh_info = pd.read_csv('Data/superhero_info.csv')
sh_info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
#read in second file to a DF
sh_powers = pd.read_csv('Data/superhero_powers.csv')
sh_powers.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
# split the 'Hero|Publisher' into 2 columns
sh_info['Hero|Publisher'].str.split('|',expand=True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
## save and rename the 2 new columns into the dataframe
sh_info[['Hero','Publisher']] = sh_info['Hero|Publisher'].str.split('|',expand=True)
sh_info.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
## drop the original column 
sh_info = sh_info.drop(columns=['Hero|Publisher'])
sh_info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero          Publisher
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb      Marvel Comics
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien  Dark Horse Comics

# %%
## examining a single value from the Measurements col
msrmnt = sh_info.loc[0,"Measurements"]
print(type(coord))
msrmnt
# Out:
# <class 'str'>
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
#create variable to replace the single quote with a douple quote
msrmnt = coord.replace("'",'"')
msrmnt
# Out:
# '{"Height": "203.0 cm", "Weight": "441.0 kg"}'

# %%
## now we can use json.loads
fixed_msrmnt = json.loads(coord)
print(type(fixed_coord))
fixed_msrmnt
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
## use .str.replace to replace all single quotes
sh_info['Measurements'] = sh_info['Measurements'].str.replace("'",'"')
## Apply the json.loads to the full column
sh_info['Measurements'] = sh_info['Measurements'].apply(json.loads)
sh_info['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
## check a single value after transformation
test_msrmnt = df.loc[0, 'Measurements']
print(type(test_msrmnt))
test_msrmnt
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
#create unique columnds for each dictionary key/value in 'Measurements'
height_weight = sh_info['Measurements'].apply(pd.Series)
height_weight
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
# add new columns to original dataframe
sh_info = pd.concat((sh_info, height_weight), axis = 1)
sh_info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
## drop the original column 
sh_info = sh_info.drop(columns=['Measurements'])
sh_info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
#rename column name
sh_powers.rename({'hero_names': 'Hero', 'Powers': 'Powers'}, axis=1, inplace=True)

# %%
#check to ensure column name is renamed
sh_powers.head()
# Out:
#           Hero                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
## showing the lists are really strings
sh_powers.loc[1,'Powers']
# Out:
# 'Accelerated Healing,Durability,Longevity,Super Strength,Stamina,Camouflage,Self-Sustenance'

# %%
#check data types
sh_powers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hero    667 non-null    object
#  1   Powers  667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB

# %%
#create list on the powers column seperated where there is a comma
sh_powers['powers_split'] = [x.split(',') for x in sh_powers['Powers'].values.tolist()]
sh_powers.head()
# Out:
#           Hero                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         powers_split
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...
# 2  [Agility, Accelerated Healing, Cold Resistance...
# 3                               [Lantern Power Ring]
# 4  [Accelerated Healing, Intelligence, Super Stre...

# %%
#see counts for each unique combination of powers
sh_powers['powers_split'].value_counts()
# Out:
# [Intelligence]                                                                                                                                                                                                                                                                          8
# [Durability, Super Strength]                                                                                                                                                                                                                                                            5
# [Agility, Stealth, Marksmanship, Weapons Master, Stamina]                                                                                                                                                                                                                               4
# ...

# %%
## exploding the column of lists
exploded = sh_powers.explode('powers_split')
exploded[['Hero','Powers', 'powers_split']].head(5)
# Out:
#       Hero                                             Powers  \
# 0  3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0  3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0  3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0  3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1   A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#           powers_split
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
## saving the unique values from the exploded column
cols_to_make = exploded['powers_split'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
#transform rows to columns for each unique Hero + Power
for col in cols_to_make:
    sh_powers[col] = sh_powers['Powers'].str.contains(col)
sh_powers.head()
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_16112\940904106.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sh_powers[col] = sh_powers['Powers'].str.contains(col)
# C:\Users\thoma\AppData\Local\Temp\ipykernel_16112\940904106.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sh_powers[col] = sh_powers['Powers'].str.contains(col)
# ...

# %%
## Merging data frames on Hero
superheros = pd.merge(sh_info,sh_powers, on='Hero')
superheros.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg  ...           False
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg  ...           False
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg  ...           False
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg  ...           False
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg  ...           False
#
#   Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# ...

# %%
# split the 'Height' into 2 columns
superheros['Height'].str.split(' ',expand=True)
superheros.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg  ...           False
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg  ...           False
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg  ...           False
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg  ...           False
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg  ...           False
#
#   Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# ...

# %%
## save and rename Height 2 new columns into the dataframe
superheros[['Height','Height_UOM']] = superheros['Height'].str.split(' ',expand=True)
superheros.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher Height    Weight  ... Omnipresent Omniscient  \
# 0      Marvel Comics  203.0  441.0 kg  ...       False      False
# 1  Dark Horse Comics  191.0   65.0 kg  ...       False      False
#
#    Hair Manipulation  Nova Force  Odin Force  Phoenix Force  \
# 0              False       False       False          False
# 1              False       False       False          False
#
#    Intuitive aptitude  Melting  Changing Armor  Height_UOM
# 0               False    False           False          cm
# 1               False    False           False          cm
#
# [2 rows x 180 columns]

# %%
## save and rename the 2 new columns into the dataframe
superheros[['Weight','Weight_UOM']] = superheros['Weight'].str.split(' ',expand=True)
superheros.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher Height Weight  ... Omniscient Hair Manipulation  \
# 0      Marvel Comics  203.0  441.0  ...      False             False
# 1  Dark Horse Comics  191.0   65.0  ...      False             False
#
#    Nova Force  Odin Force  Phoenix Force  Intuitive aptitude  Melting  \
# 0       False       False          False               False    False
# 1       False       False          False               False    False
#
#    Changing Armor  Height_UOM  Weight_UOM
# 0           False          cm          kg
# 1           False          cm          kg
#
# [2 rows x 181 columns]

# %%
#inspect data types for Height and Weight
superheros.info(['Height', 'Weight'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 463 entries, 0 to 462
# Data columns (total 181 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    Gender                        object
#  1    Race                          object
#  2    Alignment                     object
#  3    Hair color                    object
#  4    Eye color                     object
#  5    Skin color                    object
#  6    Hero                          object
#  7    Publisher                     object
#  8    Height                        object
#  9    Weight                        object
#  10   Powers                        object
#  11   powers_split                  object
#  12   Agility                       bool
#  13   Super Strength                bool
#  14   Stamina                       bool
#  15   Super Speed                   bool
#  16   Accelerated Healing           bool
#  17   Durability                    bool
# ...

# %%
#convert height to float data type
superheros['Height']=superheros['Height'].astype(float)

# %%
#convert weight to float data type
superheros['Weight']=superheros['Weight'].astype(float)

# %%
#convert height data type to INT
superheros['Height'] = superheros.Height.round().astype('Int64')

# %%
#convert weight data type to INT
superheros['Weight'] = superheros.Weight.round().astype('Int64')

# %%
#inspect to esnure data types were converted
superheros.info(['Height', 'Weight'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 463 entries, 0 to 462
# Data columns (total 181 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    Gender                        object
#  1    Race                          object
#  2    Alignment                     object
#  3    Hair color                    object
#  4    Eye color                     object
#  5    Skin color                    object
#  6    Hero                          object
#  7    Publisher                     object
#  8    Height                        Int64
#  9    Weight                        Int64
#  10   Powers                        object
#  11   powers_split                  object
#  12   Agility                       bool
#  13   Super Strength                bool
#  14   Stamina                       bool
#  15   Super Speed                   bool
#  16   Accelerated Healing           bool
#  17   Durability                    bool
# ...

# %%
#final output
superheros.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight  ... Omniscient  \
# 0         A-Bomb      Marvel Comics     203     441  ...      False
# 1     Abe Sapien  Dark Horse Comics     191      65  ...      False
# 2       Abin Sur          DC Comics     185      90  ...      False
# 3    Abomination      Marvel Comics     203     441  ...      False
# 4  Absorbing Man      Marvel Comics     193     122  ...      False
#
#   Hair Manipulation  Nova Force  Odin Force  Phoenix Force  \
# 0             False       False       False          False
# ...

# %% [markdown]
# # Part II

# %%
#average weight of super powers who have Super Speed to those who do not.
superheros.groupby('Super Speed')['Weight'].mean()
# Out:
# Super Speed
# False    101.773585
# True      129.40404
# Name: Weight, dtype: Float64

# %%
#average height of heroes for each publisher
superheros.groupby('Publisher')['Height'].mean()
# Out:
# Publisher
# DC Comics             181.92029
# Dark Horse Comics    176.909091
# George Lucas              159.6
# Image Comics              211.0
# Marvel Comics        191.545455
# Shueisha                  171.5
# Star Trek                 181.5
# Team Epic TV             180.75
# Unknown                   178.0
# Name: Height, dtype: Float64
